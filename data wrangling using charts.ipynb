# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
pd.read_csv(r"C:\Users\Dhee Whumi\Desktop\Customers.csv")
# Out:
#        CustomerKey Prefix  FirstName LastName              Unnamed: 4  \
# 0            11000    MR.        JON     YANG            MR. JON YANG
# 1            11001    MR.     EUGENE    HUANG        MR. EUGENE HUANG
# 2            11002    MR.      RUBEN   TORRES        MR. RUBEN TORRES
# 3            11003    MS.    CHRISTY      ZHU         MS. CHRISTY ZHU
# 4            11004   MRS.  ELIZABETH  JOHNSON  MRS. ELIZABETH JOHNSON
# ...            ...    ...        ...      ...                     ...
# 18143        29479    MR.      TOMMY     TANG          MR. TOMMY TANG
# 18144        29480   MRS.       NINA     RAJI          MRS. NINA RAJI
# 18145        29481    MR.       IVAN     SURI           MR. IVAN SURI
# 18146        29482    MR.    CLAYTON    ZHANG       MR. CLAYTON ZHANG
# 18147        29483    MR.      JÉSUS  NAVARRO       MR. JÉSUS NAVARRO
#
#       Unnamed: 5 Unnamed: 6   BirthDate  Unnamed: 8 MaritalStatus Gender  \
# ...

# %%
data=pd.read_csv(r"C:\Users\Dhee Whumi\Desktop\Customers.csv")
data
# Out:
#        CustomerKey Prefix  FirstName LastName              Unnamed: 4  \
# 0            11000    MR.        JON     YANG            MR. JON YANG
# 1            11001    MR.     EUGENE    HUANG        MR. EUGENE HUANG
# 2            11002    MR.      RUBEN   TORRES        MR. RUBEN TORRES
# 3            11003    MS.    CHRISTY      ZHU         MS. CHRISTY ZHU
# 4            11004   MRS.  ELIZABETH  JOHNSON  MRS. ELIZABETH JOHNSON
# ...            ...    ...        ...      ...                     ...
# 18143        29479    MR.      TOMMY     TANG          MR. TOMMY TANG
# 18144        29480   MRS.       NINA     RAJI          MRS. NINA RAJI
# 18145        29481    MR.       IVAN     SURI           MR. IVAN SURI
# 18146        29482    MR.    CLAYTON    ZHANG       MR. CLAYTON ZHANG
# 18147        29483    MR.      JÉSUS  NAVARRO       MR. JÉSUS NAVARRO
#
#       Unnamed: 5 Unnamed: 6   BirthDate  Unnamed: 8 MaritalStatus Gender  \
# ...

# %%
data.columns
# Out:
# Index(['CustomerKey', 'Prefix', 'FirstName', 'LastName', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'BirthDate', 'Unnamed: 8', 'MaritalStatus',
#        'Gender', 'EmailAddress', 'AnnualIncome', 'TotalChildren',
#        'EducationLevel', 'Occupation', 'HomeOwner', 'Unnamed: 17',
#        'Unnamed: 18', 'BirthDate.1'],
#       dtype='object')

# %%
x=(['Prefix', 'FirstName', 'LastName', 'Unnamed: 6', 'Unnamed: 17',
       'Unnamed: 18','Unnamed: 5','Unnamed: 8','BirthDate.1'])

# %%
data.drop(x, axis=1 , inplace = True)

# %%
data.rename(columns={ 'Unnamed: 4':'FullName'}, inplace = True)

# %%
data.isna().sum()
# Out:
# CustomerKey         0
# FullName            0
# BirthDate           0
# MaritalStatus       0
# Gender            130
# EmailAddress        0
# AnnualIncome        0
# TotalChildren       0
# EducationLevel      0
# Occupation          0
# HomeOwner           0
# dtype: int64

# %%
data.fillna(method = 'ffill' , inplace = True)

# %%
data
# Out:
#        CustomerKey                FullName   BirthDate MaritalStatus Gender  \
# 0            11000            MR. JON YANG    4/8/1966             M      M
# 1            11001        MR. EUGENE HUANG  14/05/1965             S      M
# 2            11002        MR. RUBEN TORRES   8/12/1965             M      M
# 3            11003         MS. CHRISTY ZHU  15/02/1968             S      F
# 4            11004  MRS. ELIZABETH JOHNSON    8/8/1968             S      F
# ...            ...                     ...         ...           ...    ...
# 18143        29479          MR. TOMMY TANG    7/4/1958             M      M
# 18144        29480          MRS. NINA RAJI  11/10/1960             S      F
# 18145        29481           MR. IVAN SURI    1/5/1960             S      M
# 18146        29482       MR. CLAYTON ZHANG    3/5/1959             M      M
# 18147        29483       MR. JÉSUS NAVARRO   12/8/1959             M      M
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18148 entries, 0 to 18147
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerKey     18148 non-null  int64
#  1   FullName        18148 non-null  object
#  2   BirthDate       18148 non-null  object
#  3   MaritalStatus   18148 non-null  object
#  4   Gender          18148 non-null  object
#  5   EmailAddress    18148 non-null  object
#  6   AnnualIncome    18148 non-null  object
#  7   TotalChildren   18148 non-null  int64
#  8   EducationLevel  18148 non-null  object
#  9   Occupation      18148 non-null  object
#  10  HomeOwner       18148 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 1.5+ MB

# %%
data.AnnualIncome
# Out:
# 0        $90,000
# 1        $60,000
# 2        $60,000
# 3        $70,000
# 4        $80,000
#            ...
# 18143    $30,000
# 18144    $30,000
# 18145    $30,000
# 18146    $30,000
# 18147    $30,000
# Name: AnnualIncome, Length: 18148, dtype: object

# %%
data.AnnualIncome=data.AnnualIncome.str.strip('$',)

# %%
data
# Out:
#        CustomerKey                FullName   BirthDate MaritalStatus Gender  \
# 0            11000            MR. JON YANG    4/8/1966             M      M
# 1            11001        MR. EUGENE HUANG  14/05/1965             S      M
# 2            11002        MR. RUBEN TORRES   8/12/1965             M      M
# 3            11003         MS. CHRISTY ZHU  15/02/1968             S      F
# 4            11004  MRS. ELIZABETH JOHNSON    8/8/1968             S      F
# ...            ...                     ...         ...           ...    ...
# 18143        29479          MR. TOMMY TANG    7/4/1958             M      M
# 18144        29480          MRS. NINA RAJI  11/10/1960             S      F
# 18145        29481           MR. IVAN SURI    1/5/1960             S      M
# 18146        29482       MR. CLAYTON ZHANG    3/5/1959             M      M
# 18147        29483       MR. JÉSUS NAVARRO   12/8/1959             M      M
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18148 entries, 0 to 18147
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerKey     18148 non-null  int64
#  1   FullName        18148 non-null  object
#  2   BirthDate       18148 non-null  object
#  3   MaritalStatus   18148 non-null  object
#  4   Gender          18148 non-null  object
#  5   EmailAddress    18148 non-null  object
#  6   AnnualIncome    18148 non-null  object
#  7   TotalChildren   18148 non-null  int64
#  8   EducationLevel  18148 non-null  object
#  9   Occupation      18148 non-null  object
#  10  HomeOwner       18148 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 1.5+ MB

# %%
data.AnnualIncome=data.AnnualIncome.str.replace(",","")

# %%
data.AnnualIncome=data.AnnualIncome.astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18148 entries, 0 to 18147
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerKey     18148 non-null  int64
#  1   FullName        18148 non-null  object
#  2   BirthDate       18148 non-null  object
#  3   MaritalStatus   18148 non-null  object
#  4   Gender          18148 non-null  object
#  5   EmailAddress    18148 non-null  object
#  6   AnnualIncome    18148 non-null  int32
#  7   TotalChildren   18148 non-null  int64
#  8   EducationLevel  18148 non-null  object
#  9   Occupation      18148 non-null  object
#  10  HomeOwner       18148 non-null  object
# dtypes: int32(1), int64(2), object(8)
# memory usage: 1.5+ MB

# %%
data.BirthDate = pd.to_datetime(data.BirthDate, format = "%d/%m/%Y")

# %%
data.BirthDate.dt.month
# Out:
# 0         8
# 1         5
# 2        12
# 3         2
# 4         8
#          ..
# 18143     4
# 18144    10
# 18145     5
# 18146     5
# 18147     8
# Name: BirthDate, Length: 18148, dtype: int32

# %%
data['BirthMonth'] = data.BirthDate.dt.month

# %%
data
# Out:
#        CustomerKey                FullName  BirthDate MaritalStatus Gender  \
# 0            11000            MR. JON YANG 1966-08-04             M      M
# 1            11001        MR. EUGENE HUANG 1965-05-14             S      M
# 2            11002        MR. RUBEN TORRES 1965-12-08             M      M
# 3            11003         MS. CHRISTY ZHU 1968-02-15             S      F
# 4            11004  MRS. ELIZABETH JOHNSON 1968-08-08             S      F
# ...            ...                     ...        ...           ...    ...
# 18143        29479          MR. TOMMY TANG 1958-04-07             M      M
# 18144        29480          MRS. NINA RAJI 1960-10-11             S      F
# 18145        29481           MR. IVAN SURI 1960-05-01             S      M
# 18146        29482       MR. CLAYTON ZHANG 1959-05-03             M      M
# 18147        29483       MR. JÉSUS NAVARRO 1959-08-12             M      M
#
#                      EmailAddress  AnnualIncome  TotalChildren  \
# ...

# %%
data.MaritalStatus = data.MaritalStatus.replace('M','Married')
data.MaritalStatus = data.MaritalStatus.replace('S','Singles')
data.Gender = data.Gender.replace('M','Man')
data.Gender = data.Gender.replace('F','Female')
data.HomeOwner = data.HomeOwner.replace('Y','Yes')
data.HomeOwner = data.HomeOwner.replace('N','No')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18148 entries, 0 to 18147
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerKey     18148 non-null  int64
#  1   FullName        18148 non-null  object
#  2   BirthDate       18148 non-null  datetime64[ns]
#  3   MaritalStatus   18148 non-null  object
#  4   Gender          18148 non-null  object
#  5   EmailAddress    18148 non-null  object
#  6   AnnualIncome    18148 non-null  int32
#  7   TotalChildren   18148 non-null  int64
#  8   EducationLevel  18148 non-null  object
#  9   Occupation      18148 non-null  object
#  10  HomeOwner       18148 non-null  object
#  11  BirthMonth      18148 non-null  int32
# dtypes: datetime64[ns](1), int32(2), int64(2), object(7)
# memory usage: 1.5+ MB

# %%
data.Gender.value_counts()
# Out:
# Gender
# Man       9189
# Female    8959
# Name: count, dtype: int64

# %%
data.Gender.value_counts().plot(kind = 'pie')
plt.title('Gender')
# Out:
# Text(0.5, 1.0, 'Gender')

# %%
data.MaritalStatus.value_counts()
# Out:
# MaritalStatus
# Married    9817
# Singles    8331
# Name: count, dtype: int64

# %%
data.MaritalStatus.value_counts().plot(kind = 'bar')
plt.title('MaritalStatus Distr.')
# Out:
# Text(0.5, 1.0, 'MaritalStatus Distr.')

# %%
data.AnnualIncome.value_counts().plot(kind = 'hist')
plt.title('AnnualIncome Distr.')
plt.xlabel('AnnualIncome')
# Out:
# Text(0.5, 0, 'AnnualIncome')

# %%
data.TotalChildren.value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='TotalChildren'>

# %%
data.Occupation.value_counts().plot(kind = 'pie')
plt.title('Occupation')
# Out:
# Text(0.5, 1.0, 'Occupation')

# %%
data.TotalChildren.value_counts().plot(kind = 'hist')
plt.title('TotalChildren Distr.')
plt.xlabel('TotalChildren')
# Out:
# Text(0.5, 0, 'TotalChildren')

# %%
data.BirthMonth.value_counts().plot(kind = 'bar')
plt.title('BirthMonth Distr.')
plt.xlabel('BirthMonth')
# Out:
# Text(0.5, 0, 'BirthMonth')

# %%
data.EducationLevel.value_counts().plot(kind = 'bar')
plt.title('EducationLevel Distr.')
plt.xlabel('EducationLevel')
# Out:
# Text(0.5, 0, 'EducationLevel')

# %%
data.HomeOwner.value_counts().plot(kind = 'bar')
plt.title('HomeOwner Status.')
plt.xlabel('HomeOwner')
# Out:
# Text(0.5, 0, 'HomeOwner')

# %%
#sns.countplot(x='TotalChildren',hue='EducationLevel', data=data)

# %%
data.groupby(['CustomerKey','EducationLevel']).size().reset_index()
# Out:
#        CustomerKey   EducationLevel  0
# 0            11000        Bachelors  1
# 1            11001        Bachelors  1
# 2            11002        Bachelors  1
# 3            11003        Bachelors  1
# 4            11004        Bachelors  1
# ...            ...              ... ..
# 18143        29479  Graduate Degree  1
# 18144        29480  Graduate Degree  1
# 18145        29481  Graduate Degree  1
# 18146        29482        Bachelors  1
# 18147        29483        Bachelors  1
#
# [18148 rows x 3 columns]

# %%
data.groupby(['CustomerKey','EducationLevel']).size().plot(kind='bar')
# Out:
# <Axes: xlabel='CustomerKey,EducationLevel'>

# %%
plt.plot(['TotalChildren','AnnualIncome'], marker='o', linestyle='-', color='b')
plt.xlabel("AnnualIncome")
plt.ylabel("TotalChildren")
plt.title("AnnualIncome by TotalChildren")
plt.show()

# %%
data.groupby(['Occupation','MaritalStatus']).size().plot(kind='pie')
# Out:
# <Axes: >

# %%
data.groupby(['Occupation','AnnualIncome']).size().plot(kind='pie')
# Out:
# <Axes: >

# %%
(now.year - data['BirthDate'].dt.year) - ((now.month - data['BirthDate'].dt.month) < 0)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18143    False
# 18144    False
# 18145    False
# 18146    False
# 18147    False
# Name: BirthDate, Length: 18148, dtype: bool

# %%
data['Age']=(now.year - data['BirthDate'].dt.year) - ((now.month - data['BirthDate'].dt.month) < 0)

# %%
data
# Out:
#        CustomerKey                FullName  BirthDate MaritalStatus  Gender  \
# 0            11000            MR. JON YANG 1966-08-04       Married     Man
# 1            11001        MR. EUGENE HUANG 1965-05-14       Singles     Man
# 2            11002        MR. RUBEN TORRES 1965-12-08       Married     Man
# 3            11003         MS. CHRISTY ZHU 1968-02-15       Singles  Female
# 4            11004  MRS. ELIZABETH JOHNSON 1968-08-08       Singles  Female
# ...            ...                     ...        ...           ...     ...
# 18143        29479          MR. TOMMY TANG 1958-04-07       Married     Man
# 18144        29480          MRS. NINA RAJI 1960-10-11       Singles  Female
# 18145        29481           MR. IVAN SURI 1960-05-01       Singles     Man
# 18146        29482       MR. CLAYTON ZHANG 1959-05-03       Married     Man
# 18147        29483       MR. JÉSUS NAVARRO 1959-08-12       Married     Man
#
# ...

# %%
data.Age.value_counts().plot(kind = 'hist')
plt.title('Age Distr.')
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %%
plt.plot(['AnnualIncome','Age'], marker='o', linestyle='-', color='b')
plt.xlabel("Age")
plt.ylabel("AnnualIncome")
plt.title("Age by AnnualIncome")
plt.show()

# %%
sns.countplot(x='HomeOwner',hue='MaritalStatus', data=data)
# Out:
# <Axes: xlabel='HomeOwner', ylabel='count'>

# %%
sns.countplot(x='TotalChildren',hue='EducationLevel', data=data)
# Out:
# <Axes: xlabel='TotalChildren', ylabel='count'>
